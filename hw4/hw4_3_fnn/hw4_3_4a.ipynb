# %%
import os
os.system('cls' if os.name == 'nt' else 'clear') # Clean the console
# Out:
# 0

# %%
import numpy as np
from keras.models import Sequential
from keras import initializers
from keras.layers import Dense, Flatten
from keras.utils import to_categorical
from keras.optimizers import SGD

# %%
input_loc = os.getcwd()

# %%
from keras.datasets import mnist
# train_images = mnist.train_images()
# train_labels = mnist.train_labels()
# test_images = mnist.test_images()
# test_labels = mnist.test_labels()

# %%
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

# %%
train_images = (train_images / 255) - 0.5
test_images = (test_images / 255) - 0.5

# %%
train_images = np.expand_dims(train_images, axis=3)
test_images = np.expand_dims(test_images, axis=3)

# %%
# weight_initializer = initializers.RandomNormal(mean=0.0, stddev=1)
weight_initializer = 'zeros'
model = Sequential([
  Flatten(),
  Dense(300, activation='sigmoid', kernel_initializer=weight_initializer),
  Dense(200, activation='sigmoid', kernel_initializer=weight_initializer),
  Dense(10, activation='softmax', kernel_initializer=weight_initializer),
])
# Out:
# Metal device set to: Apple M2 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 24.00 GB
# 2023-03-10 21:40:02.670293: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-10 21:40:02.670316: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
model.compile(SGD(lr=.008), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /Users/mac/miniconda/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
history = model.fit(
  train_images,
  to_categorical(train_labels),
  batch_size=32,
  epochs=20,
  validation_data=(test_images, to_categorical(test_labels)),
)
# Out:
# Epoch 1/20
# 2023-03-10 21:40:02.917064: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
#   15/1875 [..............................] - ETA: 13s - loss: 2.3026 - accuracy: 0.0896
# 2023-03-10 21:40:03.177981: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1870/1875 [============================>.] - ETA: 0s - loss: 2.3042 - accuracy: 0.1063
# 2023-03-10 21:40:15.440484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1875/1875 [==============================] - 14s 8ms/step - loss: 2.3043 - accuracy: 0.1064 - val_loss: 2.3026 - val_accuracy: 0.1135
# Epoch 2/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3039 - accuracy: 0.1060 - val_loss: 2.3047 - val_accuracy: 0.0980
# Epoch 3/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.3037 - accuracy: 0.1070 - val_loss: 2.3065 - val_accuracy: 0.1032
# Epoch 4/20
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.3039 - accuracy: 0.1069 - val_loss: 2.3038 - val_accuracy: 0.1135
# Epoch 5/20
# 1875/1875 [==============================] - 14s 8ms/step - loss: 2.3040 - accuracy: 0.1057 - val_loss: 2.3043 - val_accuracy: 0.1135
# Epoch 6/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3038 - accuracy: 0.1069 - val_loss: 2.3028 - val_accuracy: 0.1135
# Epoch 7/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3038 - accuracy: 0.1062 - val_loss: 2.3024 - val_accuracy: 0.1135
# Epoch 8/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3038 - accuracy: 0.1064 - val_loss: 2.3024 - val_accuracy: 0.1135
# Epoch 9/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3038 - accuracy: 0.1085 - val_loss: 2.3031 - val_accuracy: 0.1010
# Epoch 10/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3038 - accuracy: 0.1090 - val_loss: 2.3035 - val_accuracy: 0.1135
# Epoch 11/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 2.3039 - accuracy: 0.1063 - val_loss: 2.3029 - val_accuracy: 0.1135
# Epoch 12/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 2.3035 - accuracy: 0.1082 - val_loss: 2.3039 - val_accuracy: 0.1135
# Epoch 13/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 2.3037 - accuracy: 0.1086 - val_loss: 2.3045 - val_accuracy: 0.1009
# Epoch 14/20
# 1875/1875 [==============================] - 17s 9ms/step - loss: 2.3035 - accuracy: 0.1073 - val_loss: 2.3046 - val_accuracy: 0.1135
# Epoch 15/20
# 1875/1875 [==============================] - 16s 9ms/step - loss: 2.3036 - accuracy: 0.1082 - val_loss: 2.3048 - val_accuracy: 0.1010
# Epoch 16/20
# 1875/1875 [==============================] - 16s 9ms/step - loss: 2.3036 - accuracy: 0.1059 - val_loss: 2.3026 - val_accuracy: 0.0958
# Epoch 17/20
# 1875/1875 [==============================] - 16s 8ms/step - loss: 2.3034 - accuracy: 0.1072 - val_loss: 2.3013 - val_accuracy: 0.1135
# Epoch 18/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3032 - accuracy: 0.1095 - val_loss: 2.3050 - val_accuracy: 0.1032
# Epoch 19/20
# 1875/1875 [==============================] - 15s 8ms/step - loss: 2.3033 - accuracy: 0.1077 - val_loss: 2.3020 - val_accuracy: 0.1010
# Epoch 20/20
# 1875/1875 [==============================] - 16s 9ms/step - loss: 2.3036 - accuracy: 0.1052 - val_loss: 2.3020 - val_accuracy: 0.1135

# %%
import matplotlib.pyplot as plt

# print(history.history)

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
error = 1 - np.asarray(history_dict['accuracy'])
val_error = 1 - np.asarray(history_dict['val_accuracy'])
 
epochs = range(1, len(loss_values) + 1)
fig, ax = plt.subplots(1, 2, figsize=(10, 4))
#
# Plot the model accuracy vs Epochs
#
ax[0].plot(epochs, error, 'b', label='Training error')
ax[0].plot(epochs, val_error, 'orange', label='Validation error')
ax[0].set_title('Training & Validation Error Rate')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Error rate')
ax[0].set_ylim([0,1])
ax[0].legend()
#
# Plot the loss vs Epochs
#
ax[1].plot(epochs, loss_values, 'b', label='Training loss')
ax[1].plot(epochs, val_loss_values, 'orange', label='Validation loss')
ax[1].set_title('Training & Validation Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].set_ylim([0,2.5])
ax[1].legend()
#
ax[1].grid(color='gray', linestyle=':', linewidth=0.5)
ax[0].grid(color='gray', linestyle=':', linewidth=0.5)
plt.savefig(input_loc + '/hw4_3_4_4a.pdf', format='pdf', bbox_inches='tight') # Must be called before show()
